# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Load data

# %%
FARM_NAME = 'POS-data_Baechlihof.csv'
#FARM_NAME = 'POS-data_Juckerhof.csv'

df = pd.read_csv('./../data/' + FARM_NAME, sep=";", encoding="latin-1")


df['vat_percentage'] = df['vat_pos'] / df['price']

def label_restaurant(t):
    if t >= .05:
        return "restaurant"
    else:
        return "shop"
    
df['place'] = df.vat_percentage.apply(label_restaurant)
df['date'] = [d.date() for d in pd.to_datetime(df['timestamp_human'])]

# %%
def slice_df(df_, timeframe):
    if timeframe == "winter":
        return df_[df_['date'].apply(lambda d:d.month in [12, 1, 2])]
    elif timeframe == "spring":
        return df_[df_['date'].apply(lambda d:d.month in [3, 4, 5])]
    elif timeframe == "summer":
        return df_[df_['date'].apply(lambda d:d.month in [6, 7, 8])]
    elif timeframe == "fall":
        return df_[df_['date'].apply(lambda d:d.month in [9, 10, 11])]
    elif timeframe == "dayoff":
        return df_[df_['date'].apply(lambda d: (d.weekday() in [5,6]) | (d.month == 10 & d.day == 31) | (d.month == 12 & d.day == 24) | (d.month == 4 & d.day == 17))]
    else:
        return df_

# %%
TIMEFRAME = "winter"
df = slice_df(df, TIMEFRAME)

# %% [markdown]
# Focus on restaurant data

# %%
PLACE = 'restaurant'
df_ = df[df.place == PLACE]
df_transactions_full = df_.groupby('transaction_id')['article'].apply(list)

# %% [markdown]
# Applying LDA

# %%
from sklearn.feature_extraction.text import CountVectorizer
sep = "++++"
bow = CountVectorizer(vocabulary=set(df_.article.values), 
                      lowercase=False, 
                      tokenizer=lambda s: s.split(sep))
document_term_matrix = bow.fit_transform(df_transactions_full.apply(lambda s: sep.join(s)))

# %%
# %%time
from sklearn.decomposition import LatentDirichletAllocation
lda = LatentDirichletAllocation(n_components=30,
                                learning_method='batch',
                                verbose=1, 
                                evaluate_every=1 , 
                                perp_tol=1e-2, 
                                max_iter=150)
lda.fit(document_term_matrix)
# Out:
# iteration: 1 of max_iter: 150, perplexity: 174.6578
# iteration: 2 of max_iter: 150, perplexity: 111.0916
# iteration: 3 of max_iter: 150, perplexity: 88.7409
# iteration: 4 of max_iter: 150, perplexity: 79.7054
# iteration: 5 of max_iter: 150, perplexity: 75.5981
# iteration: 6 of max_iter: 150, perplexity: 74.0975
# iteration: 7 of max_iter: 150, perplexity: 73.3517
# iteration: 8 of max_iter: 150, perplexity: 73.1253
# iteration: 9 of max_iter: 150, perplexity: 72.7778
# iteration: 10 of max_iter: 150, perplexity: 71.0121
# iteration: 11 of max_iter: 150, perplexity: 70.9087
# iteration: 12 of max_iter: 150, perplexity: 70.9034
# CPU times: user 17.7 s, sys: 81.3 ms, total: 17.8 s
# Wall time: 17.8 s

# %%
lda.transform(document_term_matrix).shape
# Out:
# (11634, 30)

# %%
def print_top_words(model, feature_names, n_top_words):
    for topic_idx, topic in enumerate(model.components_):
        message = "Topic #%d: " % topic_idx
        message += "  ;  ".join([feature_names[i]
                             for i in topic.argsort()[:-n_top_words - 1:-1]])
        print(message)
    print()

# %%
pd.DataFrame(lda.components_[4]).sum()
# Out:
# 0    813.13334
# dtype: float64

# %%
topic_word.shape
# Out:
# (30, 212)

# %%
input_ = ["Bier vom Hof AMBER 5dl", "Tee"]
input_2 = ["Tee", 'Apfelstrudel mit Vanillesauce']

# %%
if input_2:
    best_topics = np.argmax(lda.transform(bow.transform(input_2)), axis=1)
    print(best_topics)
    sol = []
    for best_topic in best_topics:
        print("best topic", best_topic)
        top5_idx = topic_word[best_topic].argsort()[-5:][::-1]
        top5_probas = sorted(topic_word[best_topic], reverse=True)[:5]
        best_match_words = [bow.get_feature_names()[b] for b in top5_idx]
        sol += list(zip(best_match_words, top5_probas))
    result = list(set([(w,p) for (w,p) in sol if w not in input_2]))
    result_sorted = sorted(result, key=lambda x: x[1], reverse=True)
    sum_ = sum([p for (_,p) in result_sorted])
    result_sorted = [(w, p/sum_) for (w,p) in result_sorted] 
    print(result_sorted)
else:
    pass
# Out:
# [5 5]
# best topic 5
# best topic 5
# [('Schale', 0.71266991402690971), ('Buffet - Birchermüesli S', 0.27129887424585902), ('HofBäckerei Spezialpreis', 0.016031211727231143)]

# %%
def closest_products(lda, product_list):
    topic_word = lda.components_ / lda.components_.sum(axis=1)[:, np.newaxis]
    if product_list:
        best_topics = np.argmax(lda.transform(bow.transform(product_list)), axis=1)
        sol = []
        for best_topic in best_topics:
            top5_idx = topic_word[best_topic].argsort()[-5:][::-1] 
            top5_probas = sorted(topic_word[best_topic], reverse=True)[:5]
            best_match_words = [bow.get_feature_names()[b] for b in top5_idx]
            sol += list(zip(best_match_words, top5_probas))
        result = list(set([(w,p) for (w,p) in sol if w not in product_list]))
        result_sorted = sorted(result, key=lambda x: x[1], reverse=True)
        sum_ = sum([p for (_,p) in result_sorted])
        result_sorted = [(w, p/sum_) for (w,p) in result_sorted] # normalize the union of probas
        return result_sorted
    else:
        raise Exception("You must pass a product list")

# %% [markdown]
# # Global function

# %%
"""
timeframe; place; article_list; suggestions_list
winter
winter
...
summer
...

"""
# Out:
# '\ntimeframe; place; article_list; suggestions_list\nwinter\nwinter\n...\nsummer\n...\n\n'

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
import itertools, random
from tqdm import tqdm
from itertools import chain

# %%
FARM_NAME = 'POS-data_Baechlihof.csv'
#FARM_NAME = 'POS-data_Juckerhof.csv'
df = pd.read_csv('./../data/' + FARM_NAME, sep=";", encoding="latin-1")

df['vat_percentage'] = df['vat_pos'] / df['price']

def label_restaurant(t):
    if t >= .05:
        return "restaurant"
    else:
        return "shop"
    
df['place'] = df.vat_percentage.apply(label_restaurant)
#df['date'] = [d.date() for d in pd.to_datetime(df['timestamp'], unit="s")]
df['date'] = df.timestamp.apply(lambda d: pd.to_datetime(d, unit='s'))

# %%
def pad_10(l):
    if len(l)>=10:
        return l[:10]
    else:
        return l + [pd.np.NaN] * (len(l)-10+1)

# %%
def generate_suggestions(df_input, timeframe, place):
    
    # slice on timeframe 
    df_input = slice_df(df_input, timeframe)

    # select restaurant or shop
    df_input = df_input[df_input['place'] == place]

    # group by transactions
    df_transactions_full = df_input.groupby('transaction_id')['article'].apply(list)

    # pre process the document term matrix
    sep = "++++"
    bow = CountVectorizer(vocabulary=set(df_.article.values), 
                          lowercase=False, 
                          tokenizer=lambda s: s.split(sep))
    document_term_matrix = bow.fit_transform(df_transactions_full.apply(lambda s: sep.join(s)))

    # apply LDA
    lda = LatentDirichletAllocation(n_components=20,
                                    learning_method='batch',
                                    verbose=1, 
                                    evaluate_every=2, 
                                    perp_tol=1e-2, 
                                    max_iter=100)
    # train model
    lda.fit(document_term_matrix)

    # predict for all combinations of products of size 2
    product_combinations = list(itertools.combinations(df_input.article.unique(), 2))
    random.shuffle(product_combinations)

    tmp = []
    for combination in tqdm(product_combinations):
        suggestions = closest_products(lda, combination)
        tmp.append({"timeframe" : timeframe,
                   "place": place,
                   "article_list": combination,
                   "suggestions_list": suggestions})

    final = pd.DataFrame(tmp)

    # reformat under columns for each prediction and proba

    l = []
    for (i, row) in enumerate(final.itertuples()):
        suggestions = row.suggestions_list
        flattened = list(chain(*suggestions))
        padded_flattened = pad_10(flattened)
        tmp = dict(zip(["pred1", "prob1", "pred2", "prob2", "pred3", "prob3", "pred4", "prob4", "pred5", "prob5"], padded_flattened))
        tmp.update(final.iloc[i].to_dict())
        l.append(tmp)

    res = pd.DataFrame(l)
    res['article_list'] = res.article_list.apply(lambda t: " & ".join(t))
    del res['suggestions_list']
    return res

# %%
generate_suggestions(df_input=df, timeframe="dayoff", place="shop")
# Out:
# iteration: 1 of max_iter: 100
# iteration: 2 of max_iter: 100, perplexity: 26.7703
# iteration: 3 of max_iter: 100
# iteration: 4 of max_iter: 100, perplexity: 25.6822
# iteration: 5 of max_iter: 100
# iteration: 6 of max_iter: 100, perplexity: 25.6512
# iteration: 7 of max_iter: 100
# iteration: 8 of max_iter: 100, perplexity: 25.6544
# 100%|██████████| 22366/22366 [00:18<00:00, 1196.97it/s]
#                                             article_list place  \
# 0      Bier vom Hof AMBER 3.3dl & Suure Moscht vom Ho...  shop
# 1                           Brunch bis 12 Uhr & Brotsack  shop
# 2                             Kaffee & Fruchtschorli 5dl  shop
# 3                  Mineral Passugger 5dl & Suppe spezial  shop
# 4           Buffet - Zmorge L & Buffet - Birchermüesli L  shop
# 5      Buffet - Zmittag Salat/Warm Take away & Sultan...  shop
# 6      Buffet - Dessert S & Buffet - Zmittag Salat/Wa...  shop
# 7       Cabernet Blanc Juckerhof 2016 7.5dl & Kafi Ueli   shop
# 8      Süssmost 2dl & Fladen mit Salami klein vom Hol...  shop
# 9                              Tee vom Hof 1l & Brotsack  shop
# 10             Ketchup/Senf/Mayo Portion & Bauernturnier  shop
# 11               Süssmost 2dl & Bier vom Hof HELL 6-Pack  shop
# 12     Kürbiskernriegel & Fladen mit Käse klein vom H...  shop
# 13                  Glace Spezialpreis & Arbeiter Kaffee  shop
# 14              Apfelstrudel mit Vanillesauce & Berliner  shop
# 15       Butter Portion & Rafzer Riesling Silvaner 7.5dl  shop
# 16          Weisswein 1dl & Kürbiskernriegel mit Schoggi  shop
# 17                       Tafelwasser 1l & Schnaps Gläsli  shop
# 18             Kochlöffel & Räuschling Zürichsee AOC 5dl  shop
# 19                        Apfelstrudel & Tee vom Hof 2dl  shop
# 20                          Tee & Bier vom Hof AMBER 5dl  shop
# 21         Latte mit Aroma & Bier vom Hof PALE ALE 3.3dl  shop
# 22            Allegra 5dl PET & Bier vom Hof HELL 6-Pack  shop
# 23                Tragtasche klein & Himbeeren Likör 2dl  shop
# 24                 Sandwich Mostbröckli & Schnaps Gläsli  shop
# 25              Buffet - Dessert Take away & Schnaps 1dl  shop
# 26        Chnuspergipfeli & Räuschling Zürichsee AOC 5dl  shop
# 22355                   Brunch bis 13 Uhr
# 22356                   Brunch bis 13 Uhr
# 22357                    Tragtasche klein
# 22358                   Brunch bis 13 Uhr
# 22359                  Glace Spezialpreis
# 22360                   Brunch bis 13 Uhr
# 22361                   Brunch bis 13 Uhr
# 22362  Fladen mit Käse klein vom Holzofen
# 22363                   Brunch bis 13 Uhr
# 22364                   Brunch bis 13 Uhr
# 22365                   Brunch bis 13 Uhr
#
#                                             pred3  \
# 0                                Apfelschorli 5dl
# 1                                Apfelschorli 5dl
# 2                                Tragtasche klein
# 3                                Apfelschorli 5dl
# 4                                Apfelschorli 5dl
# 5                                Apfelschorli 5dl
# 6                                Apfelschorli 5dl
# 7                                Apfelschorli 5dl
# 8                                Tragtasche klein
# 9                                Apfelschorli 5dl
# 10                               Apfelschorli 5dl
# 11                               Apfelschorli 5dl
# 12                                 Büffel Knebele
# 13                                 Büffel Knebele
# 14                               Apfelschorli 5dl
# 15                               Apfelschorli 5dl
# 16                               Apfelschorli 5dl
# 17                               Apfelschorli 5dl
# 18                               Apfelschorli 5dl
# 19                               Apfelschorli 5dl
# 20                               Apfelschorli 5dl
# 21                               Apfelschorli 5dl
# 22                               Apfelschorli 5dl
# 23     Fladen mit Artischocken klein vom Holzofen
# 24                               Apfelschorli 5dl
# 25                               Tragtasche klein
# 26                               Apfelschorli 5dl
# 27                               Apfelschorli 5dl
# 28                               Apfelschorli 5dl
# 29                               Apfelschorli 5dl
# ...                                           ...
# 22336                            Apfelschorli 5dl
# 22337                              Büffel Knebele
# 22338                            Apfelschorli 5dl
# 22339                            Apfelschorli 5dl
# 22340                            Apfelschorli 5dl
# 22341                            Apfelschorli 5dl
# 22342                            Apfelschorli 5dl
# 22343                           Brunch bis 13 Uhr
# 22344                            Apfelschorli 5dl
# 22345                            Apfelschorli 5dl
# 22346                            Apfelschorli 5dl
# 22347                            Apfelschorli 5dl
# 22348                            Apfelschorli 5dl
# 22349                            Tragtasche klein
# 22350                            Apfelschorli 5dl
# 22351                            Tragtasche klein
# 22352                Fladen mit Käse vom Holzofen
# 22353                           Brunch bis 13 Uhr
# 22354                            Tragtasche klein
# 22355                            Apfelschorli 5dl
# 22356                            Apfelschorli 5dl
# 22357                           Brunch bis 13 Uhr
# 22358                            Apfelschorli 5dl
# 22359                              Büffel Knebele
# 22360                            Apfelschorli 5dl
# 22361                            Apfelschorli 5dl
# 22362                          Glace Spezialpreis
# 22363                            Apfelschorli 5dl
# 22364                            Apfelschorli 5dl
# 22365                            Apfelschorli 5dl
#
#                                             pred4  \
# 0      Fladen mit Artischocken klein vom Holzofen
# 1      Fladen mit Artischocken klein vom Holzofen
# 2                               Brunch bis 13 Uhr
# 3      Fladen mit Artischocken klein vom Holzofen
# 4      Fladen mit Artischocken klein vom Holzofen
# 5      Fladen mit Artischocken klein vom Holzofen
# 6      Fladen mit Artischocken klein vom Holzofen
# 7      Fladen mit Artischocken klein vom Holzofen
# 8                               Brunch bis 13 Uhr
# 9      Fladen mit Artischocken klein vom Holzofen
Buffet - Zmittag Salat/Warm Take away  0.200000  0.200000
# 27          Buffet - Zmittag Salat/Warm Take away  0.200000  0.200000
# 28          Buffet - Zmittag Salat/Warm Take away  0.200000  0.200000
# 29          Buffet - Zmittag Salat/Warm Take away  0.200000  0.200000
# ...                                           ...       ...       ...
# 22336       Buffet - Zmittag Salat/Warm Take away  0.200000  0.200000
# 22337                            Tragtasche klein  0.344726  0.268333
# 22338       Buffet - Zmittag Salat/Warm Take away  0.200000  0.200000
# 22339       Buffet - Zmittag Salat/Warm Take away  0.200000  0.200000
# 22340       Buffet - Zmittag Salat/Warm Take away  0.200000  0.200000
# 22341       Buffet - Zmittag Salat/Warm Take away  0.200000  0.200000
# 22342       Buffet - Zmittag Salat/Warm Take away  0.200000  0.200000
# 22343  Fladen mit Artischocken klein vom Holzofen  0.799288  0.035770
# 22344       Buffet - Zmittag Salat/Warm Take away  0.200000  0.200000
# 22345       Buffet - Zmittag Salat/Warm Take away  0.200000  0.200000
# 22346       Buffet - Zmittag Salat/Warm Take away  0.200000  0.200000
# 22347       Buffet - Zmittag Salat/Warm Take away  0.200000  0.200000
# 22348       Buffet - Zmittag Salat/Warm Take away  0.200000  0.200000
# 22349                            Apfelschorli 5dl  0.693584  0.250926
# 22350       Buffet - Zmittag Salat/Warm Take away  0.200000  0.200000
# 22351                            Apfelschorli 5dl  0.567536  0.342769
# 22352              Fladen mit Salami vom Holzofen  0.361050  0.265372
# 22353       Buffet - Zmittag Salat/Warm Take away  0.980706  0.004747
# 22354                            Apfelschorli 5dl  0.911332  0.061915
# 22355       Buffet - Zmittag Salat/Warm Take away  0.200000  0.200000
# 22356       Buffet - Zmittag Salat/Warm Take away  0.200000  0.200000
# 22357  Fladen mit Artischocken klein vom Holzofen  0.799288  0.035770
# 22358       Buffet - Zmittag Salat/Warm Take away  0.200000  0.200000
# 22359                            Tragtasche klein  0.344726  0.268333
# 22360       Buffet - Zmittag Salat/Warm Take away  0.200000  0.200000
# 22361       Buffet - Zmittag Salat/Warm Take away  0.200000  0.200000
# 22362                            Tragtasche klein  0.385481  0.239516
# 22363       Buffet - Zmittag Salat/Warm Take away  0.200000  0.200000
# 22364       Buffet - Zmittag Salat/Warm Take away  0.200000  0.200000
# 22365       Buffet - Zmittag Salat/Warm Take away  0.200000  0.200000
#
#           prob3     prob4     prob5 timeframe
# 0      0.200000  0.200000  0.200000    dayoff
# 1      0.200000  0.200000  0.200000    dayoff
# 2      0.006236  0.006236  0.006236    dayoff
# 3      0.200000  0.200000  0.200000    dayoff
# 4      0.200000  0.200000  0.200000    dayoff
# 5      0.202150  0.202150  0.178349    dayoff
# 6      0.202150  0.202150  0.178349    dayoff
# 7      0.200000  0.200000  0.200000    dayoff
# 8      0.009372  0.009372  0.009372    dayoff
# 9      0.200000  0.200000  0.200000    dayoff
# 10     0.200000  0.200000  0.200000    dayoff
# 11     0.200000  0.200000  0.200000    dayoff
# 12     0.190182  0.095486  0.006819    dayoff
# 13     0.178889  0.089815  0.006414    dayoff
# 14     0.200000  0.200000  0.200000    dayoff
# 15     0.200000  0.200000  0.200000    dayoff
# 16     0.200000  0.200000  0.200000    dayoff
# 17     0.200000  0.200000  0.200000    dayoff
# 18     0.200000  0.200000  0.200000    dayoff
# 19     0.200000  0.200000  0.200000    dayoff
# 20     0.200000  0.200000  0.200000    dayoff
# 21     0.200000  0.200000  0.200000    dayoff
# 22     0.200000  0.200000  0.200000    dayoff
# 23     0.244357  0.244357  0.005643    dayoff
# 24     0.200000  0.200000  0.200000    dayoff
# 25     0.009550  0.009550  0.009550    dayoff
# 26     0.200000  0.200000  0.200000    dayoff
# 27     0.200000  0.200000  0.200000    dayoff
# 28     0.200000  0.200000  0.200000    dayoff
# 29     0.200000  0.200000  0.200000    dayoff
# ...         ...       ...       ...       ...
# 22336  0.200000  0.200000  0.200000    dayoff
# 22337  0.230136  0.115545  0.008252    dayoff
# 22338  0.200000  0.200000  0.200000    dayoff
# 22339  0.200000  0.200000  0.200000    dayoff
# 22340  0.200000  0.200000  0.200000    dayoff
# 22341  0.200000  0.200000  0.200000    dayoff
# 22342  0.200000  0.200000  0.200000    dayoff
# 22343  0.035770  0.035770  0.035770    dayoff
# 22344  0.200000  0.200000  0.200000    dayoff
# 22345  0.200000  0.200000  0.200000    dayoff
# 22346  0.200000  0.200000  0.200000    dayoff
# 22347  0.200000  0.200000  0.200000    dayoff
# 22348  0.200000  0.200000  0.200000    dayoff
# iteration: 3 of max_iter: 100
# iteration: 4 of max_iter: 100, perplexity: 25.5104
# iteration: 5 of max_iter: 100
# iteration: 6 of max_iter: 100, perplexity: 183.8726
# iteration: 7 of max_iter: 100
# iteration: 8 of max_iter: 100, perplexity: 183.8678
# 100%|██████████| 125250/125250 [08:06<00:00, 257.52it/s]
# iteration: 1 of max_iter: 100
# iteration: 2 of max_iter: 100, perplexity: 90.1741
# iteration: 3 of max_iter: 100
# iteration: 4 of max_iter: 100, perplexity: 71.3688
# iteration: 5 of max_iter: 100
# iteration: 6 of max_iter: 100, perplexity: 66.6055
# iteration: 7 of max_iter: 100
# iteration: 8 of max_iter: 100, perplexity: 65.4376
# iteration: 9 of max_iter: 100
# iteration: 10 of max_iter: 100, perplexity: 65.2805
# iteration: 11 of max_iter: 100
# iteration: 12 of max_iter: 100, perplexity: 65.2505
# iteration: 13 of max_iter: 100
# iteration: 14 of max_iter: 100, perplexity: 65.2436
# 100%|██████████| 27730/27730 [00:24<00:00, 1136.68it/s]
# iteration: 1 of max_iter: 100
# iteration: 2 of max_iter: 100, perplexity: 25.6902
# iteration: 3 of max_iter: 100
# iteration: 4 of max_iter: 100, perplexity: 24.3521
# iteration: 5 of max_iter: 100
# iteration: 6 of max_iter: 100, perplexity: 53.2291
# iteration: 7 of max_iter: 100
# iteration: 8 of max_iter: 100, perplexity: 52.9716
# iteration: 9 of max_iter: 100
# iteration: 10 of max_iter: 100, perplexity: 52.9717
# 100%|██████████| 285390/285390 [04:13<00:00, 1125.08it/s]
# iteration: 1 of max_iter: 100
# iteration: 2 of max_iter: 100, perplexity: 102.3138
# iteration: 3 of max_iter: 100
# iteration: 4 of max_iter: 100, perplexity: 79.9350
# iteration: 5 of max_iter: 100
# iteration: 6 of max_iter: 100, perplexity: 74.6582
# iteration: 7 of max_iter: 100
# iteration: 8 of max_iter: 100, perplexity: 73.6013
# iteration: 9 of max_iter: 100
# iteration: 10 of max_iter: 100, perplexity: 73.4235
# iteration: 11 of max_iter: 100
# iteration: 12 of max_iter: 100, perplexity: 73.3983
# iteration: 13 of max_iter: 100
# iteration: 14 of max_iter: 100, perplexity: 73.3937
# 100%|██████████| 53301/53301 [00:49<00:00, 1076.69it/s]

# %%
concatenation = pd.concat(l)

# %%
concatenation.to_csv("bundles.csv")

# %%
concatenation.pred5.value_counts()
# Out:
# Joghurt 180g Himbeer Rhabarber           260341
# Flammkuchen                              143588
# Tragtasche klein                         142255
# Buffet - Zmittag Salat/Warm Take away    135282
# HofBäckerei Spezialpreis                 119726
# Fladen mit Käse vom Holzofen              16115
# Bier vom Hof HELL 5dl                     12891
# Fruchtschorli 5dl                          5825
# Brötli vom Hof                             5581
# Fladen mit Schinken vom Holzofen           5384
# Quöllfrisch 5dl                            5374
# Quöllfrisch 3.3dl                          5176
# Suure Moscht vom Hof mit Alkohol 5dl       4947
# Brunch bis 13 Uhr                          4787
# Apfelschorli 5dl                           4699
# pa es 2.75dl                               4535
# Knobliwurst                                4159
# Suppe                                      3983
# Buffet - Birchermüesli Take away           3848
# Flamm kuchen Vom Garte                     3828
# Grosi's Gugelhopf Schoggi                  3692
# Fladen mit Salami klein vom Holzofen       3626
# Bier vom Hof AMBER 5dl                     3364
# Cappuccino                                 3296
# Berliner                                   3258
# Kürbiskernriegel mit Schoggi               3122
# Fladen mit Salami vom Holzofen             2977
# Buffet - Zmorge L                          2971
# Tragtasche gross                           2859
# Schoggistängeli                            2785
#                                           ...
# Apfel-Birnen Pausenapfel                     62
# Erdbeer Schaumwein 7.5dl                     55
# Büffel Schüblig                              38
# Schnaps 5dl                                  31
# Dessertquark Heidelbeer                      27
# Joghurt 500g Himbeer Rhabarber               23
# Gipfeli vom Hof                              23
# Ketchup/Senf/Mayo Portion                    21
# Rotwein 1dl                                  20
# Dessert im Glas mini                         18
# Geschenksäckli                               15
# Tröpfel Brut 7.5dl                           14
# Glace Kübeli                                 12
# Getränke alkoholfrei Spezialpreis            12
# Tee vom Hof 1dl                              12
# Glace Spezialpreis                           10
# Büffel Salami                                10
# Bier vom Hof AMBER 6-Pack                     9
# Kindergeburtstag                              9
# Kindernachmittag                              8
# Fruchtstange                                  7
# Prosecco Colli Nobili 7.5dl                   7
# Quintener Federweisser 5dl                    6
# Erdbeerwein 5dl (3er-Karton)                  6
# Holzdeckel klein                              4
# Kafi Ueli                                     3
# Süssmost 1.5l                                 3
# Fladen Caprese vom Holzofen                   2
# Cabernet Blanc Juckerhof 2016 7.5dl           1
# Buffet - Birchermüesli L                      1
# Name: pred5, Length: 140, dtype: int64
