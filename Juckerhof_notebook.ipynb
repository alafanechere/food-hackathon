# %%
import os
import pandas

os.chdir('/Users/jacquelinestahlin/Documents/Private/Projects/HackathonLausanne/Hackdays')

df_baechlihof = pandas.read_csv('POS-data_Baechlihof.csv',sep=';')
df_juckerhof = pandas.read_csv('POS-data_Juckerhof.csv',sep=';')
df_meteo = pandas.read_csv('weather-data.csv',sep=';')

print df_baechlihof.columns.values
print df_juckerhof.columns.values
# Out:
# ['timestamp' 'timestamp_human' 'shop' 'transaction_id' 'cost_unit'
#  'position_id' 'article' 'count' 'unit' 'article_group0' 'article_group1'
#  'article_group2' 'vat_pos' 'price']
# ['timestamp' 'timestamp_human' 'shop' 'transaction_id' 'cost_unit'
#  'position_id' 'article' 'count' 'unit' 'article_group0' 'article_group1'
#  'article_group2' 'vat_pos' 'price']

# %%
print df_juckerhof
# Out:
#          timestamp   timestamp_human                 shop  transaction_id  \
# 0       1485937064  01.02.2017 08:17  Juckerhof Seegr�ben         2621812
# 1       1485938709  01.02.2017 08:45  Juckerhof Seegr�ben         2621813
# 2       1485938709  01.02.2017 08:45  Juckerhof Seegr�ben         2621813
# 3       1485939854  01.02.2017 09:04  Juckerhof Seegr�ben         2621814
# 4       1485939896  01.02.2017 09:04  Juckerhof Seegr�ben         2621815
# 5       1485940123  01.02.2017 09:08  Juckerhof Seegr�ben         2621816
# 6       1485940123  01.02.2017 09:08  Juckerhof Seegr�ben         2621816
# 7       1485940242  01.02.2017 09:10  Juckerhof Seegr�ben         2621817
# 8       1485940881  01.02.2017 09:21  Juckerhof Seegr�ben         2621818
# 9       1485940881  01.02.2017 09:21  Juckerhof Seegr�ben         2621818
# 10      1485940881  01.02.2017 09:21  Juckerhof Seegr�ben         2621818
# 11      1485940881  01.02.2017 09:21  Juckerhof Seegr�ben         2621818
# ...

# %%
print df_meteo
# Out:
#             date  temperature  precipitation  snowfraction  sealevelpressure  \
# 0     1483228800         1.72            NaN           NaN            1032.0
# 1     1483232400         1.71            NaN           NaN            1032.0
# 2     1483236000         1.90            NaN           NaN            1030.0
# 3     1483239600         2.01            NaN           NaN            1030.0
# 4     1483243200         1.90            NaN           NaN            1030.0
# 5     1483246800         2.05            NaN           NaN            1029.0
# 6     1483250400         2.13            NaN           NaN            1028.0
# 7     1483254000         2.14            NaN           NaN            1028.0
# 8     1483257600         2.53            NaN           NaN            1028.0
# 9     1483261200         3.30            NaN           NaN            1027.0
# 10    1483264800         3.71            NaN           NaN            1027.0
# ...

# %% [markdown]
# # Time Aggregation
